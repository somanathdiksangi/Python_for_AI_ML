# %%
import numpy as np

# %%
np.array([1,2,35,1])
# Out:
# array([ 1,  2, 35,  1])

# %%
np.asarray([5,6,95,96])
# Out:
# array([ 5,  6, 95, 96])

# %%
x=np.random.rand(3,3)
x
# Out:
# array([[0.6195852 , 0.19479182, 0.18030944],
#        [0.28601991, 0.61958204, 0.8145965 ],
#        [0.9888299 , 0.36177537, 0.00231514]])

# %%
import pandas as pd
pd.DataFrame(x)
# Out:
#           0         1         2
# 0  0.868069  0.758184  0.053589
# 1  0.677181  0.866325  0.382713
# 2  0.096401  0.532674  0.110401

# %%
linspace
logspace

# %%
np.linspace(0,10,10)
# Out:
# array([ 0.        ,  1.11111111,  2.22222222,  3.33333333,  4.44444444,
#         5.55555556,  6.66666667,  7.77777778,  8.88888889, 10.        ])

# %%
np.linspace(0,10,1000)
# Out:
# array([ 0.        ,  0.01001001,  0.02002002,  0.03003003,  0.04004004,
#         0.05005005,  0.06006006,  0.07007007,  0.08008008,  0.09009009,
#         0.1001001 ,  0.11011011,  0.12012012,  0.13013013,  0.14014014,
#         0.15015015,  0.16016016,  0.17017017,  0.18018018,  0.19019019,
#         0.2002002 ,  0.21021021,  0.22022022,  0.23023023,  0.24024024,
#         0.25025025,  0.26026026,  0.27027027,  0.28028028,  0.29029029,
#         0.3003003 ,  0.31031031,  0.32032032,  0.33033033,  0.34034034,
#         0.35035035,  0.36036036,  0.37037037,  0.38038038,  0.39039039,
#         0.4004004 ,  0.41041041,  0.42042042,  0.43043043,  0.44044044,
#         0.45045045,  0.46046046,  0.47047047,  0.48048048,  0.49049049,
#         0.5005005 ,  0.51051051,  0.52052052,  0.53053053,  0.54054054,
#         0.55055055,  0.56056056,  0.57057057,  0.58058058,  0.59059059,
#         0.6006006 ,  0.61061061,  0.62062062,  0.63063063,  0.64064064,
# ...

# %%
np.logspace(1,10,10)
# Out:
# array([1.e+01, 1.e+02, 1.e+03, 1.e+04, 1.e+05, 1.e+06, 1.e+07, 1.e+08,
#        1.e+09, 1.e+10])

# %% [markdown]
# ## 1.we can create a array np.array() np.asarray
# ## 2.we can genrate a array with random number (rand,randn,randint,arange,choice)
# ## 3.we can genrate some specific array like ones zeros full with any value or empty and empty like
# ## 3.evenly spaced valued array linspace and logspace

# %% [markdown]
# ## now we have to slicing

# %%
a=np.array([1,2,3,4,5,6])

# %%
a.shape
# Out:
# (6,)

# %%
a=np.array([[1,2],[4,5]])

# %%
a.shape
# Out:
# (2, 2)

# %%
a.ndim
# Out:
# 2

# %%
  a=np.array([1,2,3,4,5,6])

# %%
a[0]
# Out:
# 1

# %%
a[1:4]
# Out:
# array([2, 3, 4])

# %%
a[-2]
# Out:
# 5

# %%
a=np.array([[1,2],[4,5]])

# %%
a[0][1]
# Out:
# 2

# %%
a[0,1]
# Out:
# 2

# %%
c=np.array([[[1,2],[3,4]],[[5,6],[7,8]]])

# %%
c
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [7, 8]]])

# %%
a
# Out:
# array([[1, 2],
#        [4, 5]])

# %%
a[0,:]
# Out:
# array([1, 2])

# %%
a[:,1]
# Out:
# array([2, 5])

# %%
a=np.array([[1,2,3],[4,5,6]])

# %%
a
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a[0:2,1:3]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
a[2:2]
# Out:
# array([], shape=(0, 3), dtype=int32)
