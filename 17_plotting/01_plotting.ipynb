# %%
import pandas as pd

# %%
data=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
line
scatter plot
bar plot
histogram
pie
box
violin
heatmap
3d plot
# Out:
#   Cell In[4], line 9
#     3d plot
#     ^
# SyntaxError: invalid decimal literal

# %%
univariate-->> single variable

bivariate-->> two column

multivariate-->> more than 3 column

# %%
variable  wise or column wise

numarical vari
categorical vari

# %%
two dimesion
three dimesion

# %%
data['SepalLengthCm'].plot()
data['SepalWidthCm'].plot()
data['PetalLengthCm'].plot()

# %%
data['SepalLengthCm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## ineplot(data=None, *, x=None, y=None, hue=None, size=None, style=None, units=None, weights=None, palette=None, hue_order=None, hue_norm=None, sizes=None, size_order=None, size_norm=None, dashes=True, markers=None, style_order=None, estimator='mean', errorbar=('ci', 95), n_boot=1000, seed=None, orient='x', sort=True, err_style='band', err_kws=None, legend='auto', ci='deprecated', ax=None, **kwargs)

# %%
data2=pd.read_csv("https://raw.githubusercontent.com/sunnysavita10/Statistics-With-Python-CompleteGuide/refs/heads/main/Titanic.csv")

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2['Pclass'].plot(kind='bar')
# Out:
# <Axes: >

# %%
data2['Pclass'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#data2['Cabin'].plot(kind='bar')

# %%
data2['Pclass'].plot(kind='pie')
# Out:
# <Axes: ylabel='Pclass'>

# %%
d=data2['Pclass'].value_counts()

# %%
d.plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
d.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10,100)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
# ...

# %%
plt.plot(x)

# %%
y=np.sin(x)

# %%
plt.plot(y)

# %%
fig,ax=plt.subplot()
ax.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 fig,ax=plt.subplot()
#       2 ax.plot(x,y)
#
# TypeError: cannot unpack non-iterable Axes object

# %%
x=np.random.randn(100)
y=np.random.randn(100)

# %%
plt.scatter(x,y)

# %%
fig, ax = plt.subplots()
plt.scatter(x,y)
ax.set_xlable('x-axis')
ax.set_ylable('y-axis')
ax.tittle("scatter")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 3
#       1 fig, ax = plt.subplots()
#       2 plt.scatter(x,y)
# ----> 3 ax.set_xlable('x-axis')
#       4 ax.set_ylable('y-axis')
#       5 ax.tittle("scatter")
#
# AttributeError: 'Axes' object has no attribute 'set_xlable'

# %%
import matplotlib.pyplot as plt


x = np.random.randn(100)
y = np.random.randn(100)

# Create the figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(x, y)

# Set axis labels
ax.set_xlabel('x-axis')  # Corrected from set_xlable
ax.set_ylabel('y-axis')  # Corrected from set_ylable

# Set the title
ax.set_title("Scatter")  # Corrected from ax.tittle

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt


x = data2['Age']
y = data2['Pclass']

# Create the figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.scatter(x, y)

# Set axis labels
ax.set_xlabel('x-axis')  # Corrected from set_xlable
ax.set_ylabel('y-axis')  # Corrected from set_ylable

# Set the title
ax.set_title("Scatter")  # Corrected from ax.tittle

# Show the plot
plt.show()

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
x=['A','B','C','D','E']
y=[5,6,8,6,5]

fig, ax = plt.subplots()

# Create a scatter plot
ax.bar(x, y)

# Set axis labels
ax.set_xlabel('x-axis')  # Corrected from set_xlable
ax.set_ylabel('y-axis')  # Corrected from set_ylable

# Set the title
ax.set_title("bar")  # Corrected from ax.tittle

# Show the plot
plt.show()

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data2['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
x=data2['Pclass']
y=data2['Age']
fig  , ax= plt.subplots()
ax.bar(x,y)
# Out:
# <BarContainer object of 891 artists>

# %%
y=data2['Age']
fig  , ax= plt.subplots()
ax.hist(y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=['A','B','C','D','E']
y=[5,6,8,6,5]


# Create the figure and axes
fig, ax = plt.subplots()

# Create a scatter plot
ax.pie(y,labels=x)

# Set axis labels
ax.set_xlabel('x-axis')  # Corrected from set_xlable
ax.set_ylabel('y-axis')  # Corrected from set_ylable

# Set the title
ax.set_title("pie")  # Corrected from ax.tittle

# Show the plot
plt.show()

# %%
univarient 
bivariate
1.x-num y-num
2.x-cat y-cat
3.x-num y -cat

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
x = [1, 1, 2, 2]
y = [1, 2, 1, 2]
z = [0, 0, 0, 0]
dx = np.ones_like(x)*0.5
dy = np.ones_like(x)*0.5
dz = [2, 3, 1, 4]

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.bar3d(x, y, z, dx, dy, dz)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('_mpl-gallery')

# Make data
np.random.seed(19680801)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import axes3d

plt.style.use('_mpl-gallery')

# Make data
X, Y, Z = axes3d.get_test_data(0.05)

# Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %%
import seaborn as sns
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")

# %%
sns.displot(penguins, x="flipper_length_mm", hue="species", element="step")

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']
